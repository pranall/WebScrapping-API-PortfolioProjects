# %% [markdown]
# Warm Greetings!
#
# 1) Naukri.com, one of the most popular was used for the detailed analysis for the Job Title: "Data Scientist" and the location is set to "India".
#
# 2) Using the Web Scrapping process, around 12,000 job's data was scrapped as per the Job Title of 'Data Scientist' from location 'India'.
#
# 3) The following professional report provides insights about detailed Job Market Analysis in both code and Pictorial manner for better understanding.

# %% [markdown]
# ***Job Market Analysis Report.***
#
# A) Data collection method (include the sample size & process of data collection)
#
# Data Exploration and Visualization Report.
#
# ***Introduction:***
#
# Warm Greetings!
#
# 1) Naukri.com, one of the most popular was used for the detailed analysis for the Job Title: "Data Scientist" and the location is set to "India".
#
# 2) Using the Web Scrapping process, around 12,000 job's data was scrapped as per the Job Title of 'Data Scientist' from location 'India'.
#
# 3) The following professional report provides insights about detailed Job Market Analysis in both code and Pictorial manner for better understanding.
#
# ***Data Collection Method:***
#
# **Website:** Naukri.com
#
# **Keywords:** Data Scientist (also contains other roles like :Data Engineer ML Engineer, etc for helpful data analysis but focuses more on Data Scientist Role).
#
# **Sample Size:** Collected data from 12000 job postings.
#
# ***Process of Data Collection:***
#
# 1) Utilized web scraping techniques with Python libraries like BeautifulSoup.
#
# 2) Extracted information including job title, company, location, job type, and required skills.

# %%
import requests
session = requests.Session()

#Increase the redirect count to 40
session.max_redirects = 40
session.get("https://www.naukri.com/data-scientist-jobs-in-india?k=data%20scientist&l=india&nignbevent_src=jobsearchDeskGNB")
url = "https://www.naukri.com/data-scientist-jobs-in-india?k=data%20scientist&l=india&nignbevent_src=jobsearchDeskGNB"
needed_headers = {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"}
response = requests.get(("https://www.naukri.com/data-scientist-jobs-in-india?k=data%20scientist&l=india&nignbevent_src=jobsearchDeskGNB"),headers = needed_headers,allow_redirects=False)

# %%
if response.status_code == 200:
    print("Request was successful. Status code:", response.status_code)
else:
    print("Request failed. Status code:", response.status_code)
# Out:
# Request was successful. Status code: 200

# %%
web_content = response.text
print("Content of the webpage:")
print(web_content)
# Out:
# Content of the webpage:
# ...

# %%
print("First 200 characters of the content:")
print(web_content[:200])
# Out:
# First 200 characters of the content:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="stylesheet" href="https://static.naukimg.com/s/9/121/_next/stat

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(web_content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/e30146f59d01ccf5.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d006e676502fe1bd.css" rel="stylesheet"/>
# ...

# %% [markdown]
# The Web Scrapping process continued and it is not mentioned in detailed as the main focus was on visualizations and job analysis.
#
# The data was stored as naukriscrappeddata.csv.

# %% [markdown]
# Exporting the CSV

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eca2ee01-f154-467f-be33-cf3b21f29b0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eca2ee01-f154-467f-be33-cf3b21f29b0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# B) Market Data Visualization
#
# When there are large amounts of data available it is frequently useful to create a data visualization. Use the plotting tools introduced in the class or spreadsheet tools to create visualizations for at least any two of the data elements listed below. Use tabular format to represent any data that is not in a graphical format. Graphic can include any combination of histograms, bar charts, pie charts or other depictions.
#
# While it is not required, it might be interesting to you to create multivariate graphs such as but not limited to location and salary on the same graph.
# - Titles of positions available
# - Locations where the roles are offered (including remote)
# - Type of positions (Full-time or Part-time)
# - Key skills required for these positions (use appropriate visualization techniques to present
# your findings)

# %% [markdown]
# Importing the libraries

# %%
#Import libraries
import re
import pandas as pd
import folium
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.probability import FreqDist

# %%
#Load data
df=pd.read_csv("naukriscrappeddata.csv")
print('Successfully read file into Dataframe...')
# Out:
# Successfully read file into Dataframe...

# %%
#Concise summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job_Role            12000 non-null  object
#  1   Company             12000 non-null  object
#  2   Location            12000 non-null  object
#  3   Job Experience      12000 non-null  object
#  4   Skills/Description  12000 non-null  object
# dtypes: object(5)
# memory usage: 468.9+ KB

# %%
#Shape of dataframe
print('Number of Rows: {}'.format(df.shape[0]))
print('Number of Columns: {}'.format(df.shape[1]))
# Out:
# Number of Rows: 12000
# Number of Columns: 5

# %%
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
#User defined functions
def MinExp(txt):
    num = int(txt.split('-')[0])
    return num

def MaxExp(txt):
    num = int(txt.split('-')[1])
    return num

def preprocess_location(loc):
    loc=re.split('\(', loc)[0].strip()
    loc=re.sub('New Delhi','Delhi',loc)
    return loc

# %% [markdown]
# Exploratory Data Analysis
#
# Job Role

# %%
#Top 10 jobs
job_10=df['Job_Role'].value_counts()[:10].rename_axis('Job Role').reset_index(name='Count')
job_10.style.background_gradient(cmap='Greys')
# Out:
# <style type="text/css">
# #T_ec69c_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ec69c_row1_col1 {
#   background-color: #2c2c2c;
#   color: #f1f1f1;
# }
# #T_ec69c_row2_col1 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_ec69c_row3_col1 {
#   background-color: #b4b4b4;
#   color: #000000;
# }
# #T_ec69c_row4_col1, #T_ec69c_row5_col1 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_ec69c_row6_col1 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_ec69c_row7_col1 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_ec69c_row8_col1 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_ec69c_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_ec69c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec69c_level0_col0" class="col_heading level0 col0" >Job Role</th>
# ...

# %%
#Plot
dataframe = pd.DataFrame()

for job in job_10['Job Role']:
    df1 = df[df['Job_Role']==job]
    skill = [skill.lower() for skills in df1['Skills/Description'] for skill in skills.split(', ') if skill != 'IT Skills']
    fdist = FreqDist(skill)
    fdist_df=pd.DataFrame(list(dict(fdist).items()), columns=['skill', 'count'])
    fdist_df= fdist_df.sort_values(by='count', ascending=False)[:10]
    fdist_df = fdist_df.assign(job=job)
    dataframe=dataframe.append(fdist_df)

#Creating sunburst chart
fig = px.sunburst(dataframe,
                  path=['job', 'skill'],
                  values='count'
                 )
fig.update_layout(
    autosize=False,
    title_text='Top Jobs and the Required Skills',
    title_x=0.5,
    #width=1080,
    width=620,
    height=620)

#Display the figure
fig.show()
# Out:
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-106-710345bf1b7b>:11: FutureWarning:
#
# ...

# %% [markdown]
# Location of the Jobs

# %%
#Values in location column
df['Location'][:10]
# Out:
# 0    Bangalore/Bengaluru, Mumbai (All Areas)
# 1                        Bangalore/Bengaluru
# 2                        Bangalore/Bengaluru
# 3    Bangalore/Bengaluru, Mumbai (All Areas)
# 4                        Bangalore/Bengaluru
# 5                        Bangalore/Bengaluru
# 6                        Bangalore/Bengaluru
# 7    Bangalore/Bengaluru, Mumbai (All Areas)
# 8                        Bangalore/Bengaluru
# 9                                    Chennai
# Name: Location, dtype: object

# %%
##Top 10 job locations

#Splitting values and saving into a list
loc=df['Location'].tolist()
loc=[j.strip() for i in [j.strip() for i in loc for j in i.split(',')] for j in i.split('/')]

#Count
fdist = FreqDist(loc)
loc_df=pd.DataFrame(list(dict(fdist).items()), columns=['location', 'job openings'])

#Eemoving alternate names
for loc in ['Bengaluru','Secunderabad','Cochin','NCR','Gurugram']:
    loc_df=loc_df[loc_df['location']!=loc]

#Applying function
loc_df['location']=loc_df['location'].apply(preprocess_location)
loc_df=loc_df.groupby('location').sum().reset_index(level=0)

#Top 10 locations
loc_df=loc_df.sort_values(by='job openings',ascending=False)[:10]
loc_df.style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_b7834_row0_col1 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_b7834_row1_col1 {
#   background-color: #3496a9;
#   color: #f1f1f1;
# }
# #T_b7834_row2_col1 {
#   background-color: #359baa;
#   color: #f1f1f1;
# }
# #T_b7834_row3_col1 {
#   background-color: #43baad;
#   color: #f1f1f1;
# }
# #T_b7834_row4_col1 {
#   background-color: #4fc5ad;
#   color: #000000;
# }
# #T_b7834_row5_col1 {
#   background-color: #52c7ad;
#   color: #000000;
# }
# #T_b7834_row6_col1 {
#   background-color: #99ddb6;
#   color: #000000;
# }
# #T_b7834_row7_col1 {
#   background-color: #b9e6c7;
#   color: #000000;
# }
# #T_b7834_row8_col1 {
#   background-color: #d8f2e0;
#   color: #000000;
# }
# #T_b7834_row9_col1 {
#   background-color: #def5e5;
#   color: #000000;
# }
# </style>
# <table id="T_b7834" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
#Latitude and longitude of the locations
lat=[12.9716,18.5204,17.3850,19.0760,13.0827,28.4595,28.6139,28.5355,22.5726,23.0225]
lon=[77.5946,73.8567,78.4867,72.8777,80.2707,77.0266,77.2090,77.3910,88.3639,72.5714]

df1=loc_df.copy()
df1['lat']=lat
df1['lon']=lon

#Title
loc = 'Top 10 Job Locations'
title_html = '''
             <h3 align="center" style="font-size:20px"><b>{}</b></h3>
             '''.format(loc)
#Creating map
m = folium.Map(location=[20,78], tiles="OpenStreetMap", zoom_start=4.5)
m.get_root().html.add_child(folium.Element(title_html))

for i in range(0,len(df1)):
    #Marking each location
    folium.Marker(
      location=[df1.iloc[i]['lat'], df1.iloc[i]['lon']],
      popup=df1.iloc[i]['location'],
      tooltip = df1.location.values[i],
      icon=folium.Icon(icon='info-sign', color="red"),
      draggable=False
   ).add_to(m)

#Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Required Skills for the Jobs

# %%
#Top 10 demanding skills in data science jobs
skills=[j.lower() for i in df['Skills/Description'] for j in i.split(', ')]
fdist = FreqDist(skills)
skill_df=pd.DataFrame(fdist.items(),
                      columns=['Skill', 'Frequency']
                    ).sort_values('Frequency', ascending=False)[:10]
skill_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_bf582_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bf582_row1_col1 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_bf582_row2_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_bf582_row3_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_bf582_row4_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_bf582_row5_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_bf582_row6_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bf582_row7_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_bf582_row8_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_bf582_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_bf582" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
#Plot

default_color = "grey"
colors = {"python": "crimson"}

color_discrete_map = {
    c: colors.get(c, default_color)
    for c in skill_df.Skill.unique()}

fig = px.bar(skill_df, x='Frequency', y='Skill',color='Skill',orientation='h',color_discrete_map=color_discrete_map)
fig.update_layout(
    autosize=False,
    title_text='Top 10 Skills',
    title_x=0.5,
    width=600,
    height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Information about the Companies.

# %%
#Number of companies available
df['Company'].nunique()
# Out:
# 3507

# %%
#Top 10 companies
df_company=df['Company'].value_counts()[:10].rename_axis('Company').reset_index(name='Job Openings')
df_company.style.background_gradient(cmap='binary')
# Out:
# <style type="text/css">
# #T_ec764_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ec764_row1_col1 {
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_ec764_row2_col1 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_ec764_row3_col1 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_ec764_row4_col1 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_ec764_row5_col1 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_ec764_row6_col1 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_ec764_row7_col1 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_ec764_row8_col1 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_ec764_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_ec764" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
#Companies and Jobs

dataframe = pd.DataFrame()

for company in df_company['Company']:
    df1 = df[df['Company']==company]
    jobs = [job for job in df1['Job_Role']]
    fdist = FreqDist(jobs)
    fdist_df=pd.DataFrame(list(dict(fdist).items()), columns=['jobs', 'count'])
    fdist_df= fdist_df.sort_values(by='count', ascending=False)[:5]
    fdist_df = fdist_df.assign(company=company)
    dataframe=dataframe.append(fdist_df)

dataframe.head()

# Creating sunburst chart
fig = px.sunburst(dataframe,
                  path=['company', 'jobs'])
fig.update_layout(
    autosize=False,
    title_text='Top Job Providers and Jobs',
    title_x=0.5,
    width=620,
    height=620)

# Display the figure
fig.show()
# Out:
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-114-0543ae96e786>:12: FutureWarning:
#
# ...

# %% [markdown]
# Experience required in the Jobs.

# %%
#Top 10 values in 'Job Experience'
df['Job Experience'].value_counts()[:10]
# Out:
# 5-10    944
# 2-5     833
# 3-8     690
# 3-5     589
# 4-9     582
# 2-7     537
# 3-6     504
# 5-8     495
# 3-7     454
# 4-8     445
# Name: Job Experience, dtype: int64

# %%
#Outliers in 'Job Experience' column
lst=[]
for i in df['Job Experience']:
    c=False
    for j in i:
        if j.isalpha():
            c=True
    if c==True:
        lst.append(i)

lst
# Out:
# ['12 May - 21 May',
#  'B.Tech/B.E.',
#  '16 May - 22 May',
#  '18 May',
#  '12 May - 21 May',
#  '17 May - 26 May',
#  '18 May']

# %%
#Removing outliers
for j in lst:
    df=df[df['Job Experience'] != j]

# %%
#New features
df['Min. Exp.'] = df['Job Experience'].apply(MinExp)
df['Max. Exp.'] = df['Job Experience'].apply(MaxExp)

# %%
#Plot:Job Experience Demanded in Data Science Roles in India

fig = plt.figure(figsize=(14, 7), dpi=123, facecolor='#e4e5e9')
spec = fig.add_gridspec(ncols=6, nrows=2)

ax0 = fig.add_subplot(spec[0, :4])
sns.countplot(x='Min. Exp.',data=df, color='#657ffb', edgecolor='black')
plt.ylabel("Job Count", fontsize=11)
plt.xlabel('Minimum Experience', fontsize=11)
plt.xlim(0,20)
plt.ylim(0,2400)

ax1 = fig.add_subplot(spec[1, :4])
sns.countplot(x='Max. Exp.',data=df, color='#bad2ef',  edgecolor='black')
plt.ylabel("Job Count", fontsize=11)
plt.xlabel('Maximum Experience', fontsize=11)
plt.ylim(0,2400)
#plt.xlim(0,20)

ax2 = fig.add_subplot(spec[:, 4])
sns.boxplot(y=df['Min. Exp.'], color='#657ffb')
plt.xlabel('Minimum Experience',labelpad=5, fontsize=10)
plt.ylim(0,31)
plt.ylabel('')

ax3 = fig.add_subplot(spec[:, 5])
sns.boxplot(y=df['Max. Exp.'], color='#BAD2EF')
plt.xlabel('Maximum Experience',labelpad=5, fontsize=10)
plt.ylabel('')
plt.ylim(0,31)

for ax in [ax0,ax1,ax2,ax3]:
    ax.patch.set_alpha(0.0)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
fig.suptitle('Job Experience Demanded in Data Science Roles in India', fontsize=17, y=1)
plt.show()

# %%
#Average Minimum Job Experience Required Top Jobs
job_list = df['Job_Role'].value_counts().iloc[:10].index.tolist()
exp = [round(df[df['Job_Role']==job]['Min. Exp.'].mean(),2) for job in job_list]

df_job=pd.DataFrame({'Jobs':job_list, 'Average Min. Exp':exp})
df_job=df_job.sort_values('Average Min. Exp', ascending=False)
df_job
# Out:
#                                     Jobs  Average Min. Exp
# 3  Senior Technical Lead (Data Engineer)              4.99
# 5                   Senior Data Engineer              4.65
# 6                  Senior Data Scientist              4.65
# 7                    Azure Data Engineer              4.12
# 8        Data Engineer: Data Integration              3.97
# 9                      Big Data Engineer              3.62
# 0                          Data Engineer              3.53
# 1                         Data Scientist              3.43
# 4                       Business Analyst              2.64
# 2                           Data Analyst              2.55

# %% [markdown]
# Average Minimum Job Experience Required Top Jobs (In Chart Form)

# %%
from matplotlib import pyplot as plt
df_job['Average Min. Exp'].plot(kind='line', figsize=(8, 4), title='Average Min. Exp')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df_job['Average Min. Exp'].plot(kind='hist', bins=20, title='Average Min. Exp')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# C) Your ideal job (job title and relevant skills required)
#
# My ideal Job is Data Scientist with the following relevant skills.
#
# (Note: As a Data Scientist possess many skills based on the organization's requirements, multiple skills are shown below)

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("naukriscrappeddata.csv", index_col =["Job_Role", "Skills/Description"])

# retrieving rows by loc method
rows = data.loc[["Data Scientist"]]

# checking data type of rows
print(type(rows))

# display
rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                                                                              Company  \
# Job_Role       Skills/Description
# Data Scientist python, machine learning, Data Science, data an...                                                UPL
#                IT Skills, Python, Data Science, Machine Learni...                                            Walmart
#                Computer science, cassandra, Machine learning, ...                                            Walmart
#                Graphics, Bidding, Google Analytics, Data manag...                                           Ericsson
#                Computer vision, PDF, data manipulation, Machin...                            MNR Solutions Pvt. Ltd.
# ...                                                                                                              ...
# ...

# %% [markdown]
# End of the report.
#
# Note: As per the requirement, the report was supposed to be 4 pages long and code was not required, however, the images were too big to accomodate in the Word document. If the size of the images were to be reduced, the images were extremely blur and unclear the analysis was not at all visible and clear. Hence, I am attaching this document in (PDF format only).
#
# I am extremely sorry for the inconvience but I felt that at least the analysis should be clear enough for grading.
#
# If the requirement is extremely stringent to be a no-code, 4 pager report, I would try to re-submit it to the best of my ability.
#
# Thank you!
